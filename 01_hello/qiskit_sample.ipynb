# %%
# already installed in the docker image
#%pip install qiskit
#%pip install qiskit-ibm-runtime
#%pip install 'qiskit[visualization]'
#%pip install qiskit-aer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: qiskit in /usr/local/lib/python3.12/site-packages (0.45.1)
# Requirement already satisfied: qiskit-terra==0.45.1 in /usr/local/lib/python3.12/site-packages (from qiskit) (0.45.1)
# Requirement already satisfied: rustworkx>=0.13.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit) (0.13.2)
# Requirement already satisfied: numpy<2,>=1.17 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit) (1.26.3)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit) (3.11)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit) (5.9.7)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit) (1.11.4)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit) (1.12)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit) (0.3.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit) (5.1.0)
# Requirement already satisfied: symengine!=0.10.0,>=0.9 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.45.1->qiskit) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.12/site-packages (from stevedore>=3.0.0->qiskit-terra==0.45.1->qiskit) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.12/site-packages (from sympy>=1.3->qiskit-terra==0.45.1->qiskit) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: qiskit-ibm-runtime in /usr/local/lib/python3.12/site-packages (0.17.0)
# Requirement already satisfied: qiskit>=0.44.1 in /usr/local/lib/python3.12/site-packages (from qiskit-ibm-runtime) (0.45.1)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.12/site-packages (from qiskit-ibm-runtime) (2.31.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /usr/local/lib/python3.12/site-packages (from qiskit-ibm-runtime) (1.2.0)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.12/site-packages (from qiskit-ibm-runtime) (1.26.3)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.12/site-packages (from qiskit-ibm-runtime) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/site-packages (from qiskit-ibm-runtime) (2.8.2)
# Requirement already satisfied: websocket-client>=1.5.1 in /usr/local/lib/python3.12/site-packages (from qiskit-ibm-runtime) (1.7.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /usr/local/lib/python3.12/site-packages (from qiskit-ibm-runtime) (0.49.0)
# Requirement already satisfied: qiskit-ibm-provider>=0.7.2 in /usr/local/lib/python3.12/site-packages (from qiskit-ibm-runtime) (0.8.0)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.18.2 in /usr/local/lib/python3.12/site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (3.18.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.16.0)
# Requirement already satisfied: qiskit-terra==0.45.1 in /usr/local/lib/python3.12/site-packages (from qiskit>=0.44.1->qiskit-ibm-runtime) (0.45.1)
# Requirement already satisfied: rustworkx>=0.13.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.1->qiskit-ibm-runtime) (0.13.2)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.1->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.1->qiskit-ibm-runtime) (5.9.7)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.1->qiskit-ibm-runtime) (1.11.4)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.1->qiskit-ibm-runtime) (1.12)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.1->qiskit-ibm-runtime) (0.3.7)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.1->qiskit-ibm-runtime) (5.1.0)
# Requirement already satisfied: symengine!=0.10.0,>=0.9 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.1->qiskit-ibm-runtime) (0.11.0)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.12/site-packages (from qiskit-ibm-provider>=0.7.2->qiskit-ibm-runtime) (12.0)
# Requirement already satisfied: typing-extensions>=4.3 in /usr/local/lib/python3.12/site-packages (from qiskit-ibm-provider>=0.7.2->qiskit-ibm-runtime) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/site-packages (from requests>=2.19->qiskit-ibm-runtime) (2023.11.17)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.12/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (41.0.7)
# Requirement already satisfied: pyspnego>=0.1.6 in /usr/local/lib/python3.12/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.10.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (1.16.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.18.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.8.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.21)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.12/site-packages (from stevedore>=3.0.0->qiskit-terra==0.45.1->qiskit>=0.44.1->qiskit-ibm-runtime) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.12/site-packages (from sympy>=1.3->qiskit-terra==0.45.1->qiskit>=0.44.1->qiskit-ibm-runtime) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: qiskit[visualization] in /usr/local/lib/python3.12/site-packages (0.45.1)
# Requirement already satisfied: qiskit-terra==0.45.1 in /usr/local/lib/python3.12/site-packages (from qiskit[visualization]) (0.45.1)
# Requirement already satisfied: rustworkx>=0.13.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit[visualization]) (0.13.2)
# Requirement already satisfied: numpy<2,>=1.17 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit[visualization]) (1.26.3)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit[visualization]) (3.11)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit[visualization]) (5.9.7)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit[visualization]) (1.11.4)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit[visualization]) (1.12)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit[visualization]) (0.3.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit[visualization]) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit[visualization]) (5.1.0)
# Requirement already satisfied: symengine!=0.10.0,>=0.9 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit[visualization]) (0.11.0)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.12/site-packages (from qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (3.8.2)
# Requirement already satisfied: ipywidgets>=7.3.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (8.1.1)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/site-packages (from qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (2.0.0)
# Requirement already satisfied: pillow>=4.2.1 in /usr/local/lib/python3.12/site-packages (from qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (10.2.0)
# Requirement already satisfied: pylatexenc>=1.4 in /usr/local/lib/python3.12/site-packages (from qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (0.13.1)
# Requirement already satisfied: pygments>=2.4 in /usr/local/lib/python3.12/site-packages (from qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (2.17.2)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.12/site-packages (from ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.12/site-packages (from ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/site-packages (from ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (5.14.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /usr/local/lib/python3.12/site-packages (from ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /usr/local/lib/python3.12/site-packages (from ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.45.1->qiskit[visualization]) (1.16.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/site-packages (from seaborn>=0.9.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (2.1.4)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.12/site-packages (from stevedore>=3.0.0->qiskit-terra==0.45.1->qiskit[visualization]) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.12/site-packages (from sympy>=1.3->qiskit-terra==0.45.1->qiskit[visualization]) (1.3.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (3.0.43)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (4.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.12/site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (2023.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (2.4.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.3.0->qiskit-terra[visualization]; extra == "visualization"->qiskit[visualization]) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: qiskit-aer in /usr/local/lib/python3.12/site-packages (0.13.1)
# Requirement already satisfied: qiskit>=0.44.0 in /usr/local/lib/python3.12/site-packages (from qiskit-aer) (0.45.1)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.12/site-packages (from qiskit-aer) (1.26.3)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/site-packages (from qiskit-aer) (1.11.4)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/site-packages (from qiskit-aer) (5.9.7)
# Requirement already satisfied: qiskit-terra==0.45.1 in /usr/local/lib/python3.12/site-packages (from qiskit>=0.44.0->qiskit-aer) (0.45.1)
# Requirement already satisfied: rustworkx>=0.13.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.0->qiskit-aer) (0.13.2)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.0->qiskit-aer) (3.11)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.0->qiskit-aer) (1.12)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.0->qiskit-aer) (0.3.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.0->qiskit-aer) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.0->qiskit-aer) (5.1.0)
# Requirement already satisfied: symengine!=0.10.0,>=0.9 in /usr/local/lib/python3.12/site-packages (from qiskit-terra==0.45.1->qiskit>=0.44.0->qiskit-aer) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.45.1->qiskit>=0.44.0->qiskit-aer) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.12/site-packages (from stevedore>=3.0.0->qiskit-terra==0.45.1->qiskit>=0.44.0->qiskit-aer) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.12/site-packages (from sympy>=1.3->qiskit-terra==0.45.1->qiskit>=0.44.0->qiskit-aer) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from qiskit import *
from qiskit_aer import QasmSimulator
from qiskit.visualization import plot_histogram
from qiskit.tools.monitor import job_monitor

# %%
qc = QuantumCircuit()
qr = QuantumRegister(2, 'qreg')
cr = ClassicalRegister(2, 'creg')

qc.add_register(qr)
qc.add_register(cr)

qc.h(qr[0])
qc.cx(qr[0], qr[1])
qc.measure(qr, cr)

# %%
#qc.draw(output='mpl')
#/usr/local/lib/python3.12/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#  self._style, def_font_ratio = load_style(self._style)
#qc.draw(output='mpl', style="clifford")
qc.draw(output='mpl', style="iqp")

# %%
emulator = QasmSimulator()
job = execute(qc, emulator, shots=8192)
hist = job.result().get_counts()
plot_histogram(hist)
